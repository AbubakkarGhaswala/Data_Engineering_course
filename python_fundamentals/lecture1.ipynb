# %%
print("Hello World!")

# %%
print("Hello world\n How Are You")
# Out:
# Hello world
#  How Are You

# %%
user = input("Enter Your Name:- ")
print("Username is :- ",user)
# Out:
# Enter Your Name:-  hello
# Username is :-  hello

# %%
user = input("Enter Your Name:- ")
print("Username is :- ",user)
print(type(user))
# Out:
# Enter Your Name:-  hello
# Username is :-  hello
# <class 'str'>

# %%
s1 = " Abubakkar"
print(s1)
print(s1.strip())
print(s1[5])
print(len(s1))
print(s1[2:7])
print(s1[::-1])
print(s1[2:7:2])
print(s1.lower())
print(s1.upper())
print(s1.title())
print(s1.startswith("kun"))
print(s1.startswith("Abu"))
s2 = ["Abubakkar","Ghaswala"]
print(" ".join(s2))
# Out:
#  Abubakkar
# Abubakkar
# a
# 10
# bubak
# rakkabubA
# bbk
#  abubakkar
#  ABUBAKKAR
#  Abubakkar
# False
# False
# Abubakkar Ghaswala

# %%
l1 = [1,2,3,4,[2,3,4],(5,6,7),{'k1':'v1'}]
l1[4].append(99)
l1
# Out:
# [1, 2, 3, 4, [2, 3, 4, 99], (5, 6, 7), {'k1': 'v1'}]

# %%
admin = int(input("What's The Number In Your Mind! "))
user_input = int(input("Guess The Number:- "))
while user_input != admin:
    print("Wrong Guess! Try Again!")
    user_input = int(input("Guess The Number:- "))
print(f"Great You Guess{user_input} And My Mind Number Is Also {admin}")
# Out:
# What's The Number In Your Mind!  9
# Guess The Number:-  2
# Wrong Guess! Try Again!
# Guess The Number:-  2
# Wrong Guess! Try Again!
# Guess The Number:-  3
# Wrong Guess! Try Again!
# Guess The Number:-  9
# Great You Guess9 And My Mind Number Is Also 9
