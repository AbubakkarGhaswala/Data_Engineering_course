# %% [markdown]
# ### Numpy Library
# - Numpy stands for numerical python
# - This library has a lot of numerical operations that help do complex operations at a high speed.
# - Numpy is the back end of many other libraries (pandas, matplotlib)
# - There is only one type of data abstraction (data type) in numpy - numpy nd array - numpy n-dimensional array

# %%
pip install numpy
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
print(np.__version__)
#Numpy version greater than 2.0 are unstable. There are compatability issues with other functions

# %% [raw]
# !pip uninstall numpy -y
# !pip install numpy<2 --no-cache-dir
# !pip install numpy=1.26      #1.21, 1.16
# !pip install --force-reinstall numpy==1.20   #Force reinstall a specific version

# %%
arr1 = np.array(10)    #Creating a numpy array from a scalar number
arr2 = np.array([1,2,3,4,5,7])    #Creating a numpy array from a list. You can create from a tuple also
arr3 = np.array([[1,2,3],[4,5,6],[2,3,4]])  #Creating numpy array from a nested list.

# %% [markdown]
# #### Attributes of numpy array
# - type(arr) - Will tell you the datatype of the variable as a whole
# - arr.shape - Will tell you the number of rows and columns
# - arr.ndim - Will tell you how many dimensions of array the data is
# - arr.dtype - Will tell you the datatype of elements inside it
# - arr.size - Will tell you the total number of elements inside the array

# %%
print(arr1, type(arr1), arr1.shape, arr1.ndim, arr1.dtype, arr1.size)

# %%
print(arr2, type(arr2), arr2.shape, arr2.ndim, arr2.dtype, arr2.size)

# %%
print(arr3, type(arr3), arr3.shape, arr3.ndim, arr3.dtype, arr3.size)

# %%
#Numpy arrays expect symmetry, they are designed to be homogenous
a = [[1,2,3],[4,5],[6]]
print(a)

# %%
#np.array(a)   #Will throw an error because numpy arrays have to be symmetric by default

# %%
a = [[1,2,3],[4,5,'a'],[7,8,True]]
arr3 = np.array(a)

# %%
print(arr3, type(arr3), arr3.shape, arr3.ndim, arr3.dtype, arr3.size)

# %% [markdown]
# ### Homework
# - Create a numpy array from a set and dictionary and tell me your observations.

# %%
a = np.array({2,3})
print(a, type(a), a.dtype)

# %%
#Reshape function
print(arr2)
arr4 = arr2.reshape(2,3)
print()
print(arr4)
print()
print(arr2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Reshape function
# ----> 2 print(arr2)
#       3 arr4 = arr2.reshape(-1,3)
#       4 print()
#
# NameError: name 'arr2' is not defined

# %%
#arr2.reshape(4,7)  #Throws an error because elements are insufficient

# %%
#Built in array generators - arange, zeros, ones, linspace, eye, rand, randn, randint
np.arange(1,7,2)   #Generates values from start to stop in steps of 1 (or step specified)

# %%
#np.zeros(5)    #Generates a matrix filled of 0s
np.zeros((2,3,5))

# %%
#np.ones(6)   #Generats a matrix filled of 1s
np.ones((4,5))

# %%
np.linspace(3,10) #End point is inclusive by default. Generates a linear array of equally spaced count(default 50) of numbers between start and stop value

# %%
np.linspace(3,10).reshape(2,5,5)     #To reshape the output into a multi dimensional array

# %%
np.eye(5)    #Generates an identity matrix

# %%
#rand, randn, randint
np.random.rand(4,5)   #Random float values between 0 and 1 (1 is exclusive) in the shape specified

# %%
np.random.randn(3,5)   #Random float values that belong to a SND (Standard normla distribution)

# %%
np.random.randint(3,7,12)   #Generates specified count (default 1) of values randomly picked between start value and stop value

# %%
#Broadcasting in numpy
a = np.array([[2,3,4],[4,5,6],[6,7,8]])
b = np.array([5,6,7])

# %%
a+b

# %%
a*b

# %%
#Aggregations on numpy arrays
a = np.array([2,3,4,5,7,3,1,3,5,7,9,0,6,12,3,4,6,8,9])

# %%
np.min(a)   #MInimum value in the array

# %%
np.max(a)   #Maximum value in the array

# %%
np.argmin(a)    #Index position of the minimum value

# %%
np.argmax(a)     #Index position of the maximum value

# %%
np.mean(a)  #Mean value

# %%
np.median(a)   #Median

# %%
#np.where
#Task: Filter those elements which are even
np.where(a%2==0)   #Gives the indices of elements that satisfy the condition

# %%
a[np.where(a%2==0)]

# %%
#Task: Filter those elements which are greater than 5
a[np.where(a>5)]

# %%
#Indexing and Slicing
print(a)
print(a[2:7])

# %%
a = np.random.randint(2,20,30).reshape(2,3,5)
a

# %%
a[0,1:3,2:5]

# %% [markdown]
# ### Pandas is a library that helps you handle tabular data
# - Data in Pandas is stored as dataframes, a 2-d structure similar to the tables in excel
# - Pandas offers transformations, data cleaning, preprocessing options, and hence pandas library becomes an eminent part of life of DE and DS
# - Pandas offers two data abstraction models - Series and DataFrame

# %%
#Series in pandas is a 1-d data. Dataframe is a 2-d data. Other than that we do not have any dimensional data in pandas

# %%
import pandas as pd
#A series can be constructed from a list, tuple, a np.1-d array, a dictionary. But a series cannot be constructed from a set.
a = pd.Series([1,2,3,4])
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
ser1 = pd.Series((3,4,5,6),index=['row1','row2','row3','row4'],name='Series1')
ser1

# %% [markdown]
# Task: Create a pandas series with dictionary, a numpy array and a set. Observe how it is created

# %%
df = pd.DataFrame([[1,2,3,4,5],[5,6,7]])
df

# %%
df2=pd.DataFrame(ser1)
df2

# %%
df = pd.DataFrame([[1,2,3],[6,7,8],[9,4,3,2,6,8]], index=['row1','row2','row3'], columns = ['col1','col2','col3','col4','col5','col6'])
df

# %%
df.rename(columns = {'col1':'c1'}, inplace=True)   #inplace=True ensures that a permanent change is done in the variable

# %%
df

# %%
#Indexing a value or a row or a column
#df[0] #Throws an error because there is no column with name as 0
df['c1']   #Each column in a dataframe acts like a series

# %%
df[['c1','col4']]

# %%
df['c1']['row3']    #df['c1'][2] also works. For rows we can use their index also. For columns col name is compulsory

# %%
df['c1'][2]

# %%
df['col7'] =  'a'
df

# %%
df['col8'] = [5.2,6.7,8.9]
df

# %%
#File reading in pandas
#read_csv is command to read csv files, read_excel is to read excel sheets
df = pd.read_csv(r'C:\Users\Om Computers\Documents\CDE_Learning\sample_files\train.csv')
#df = pd.read_csv('train.csv')   #This works if the file is in same folder as jupyter notebook

# %%
df

# %%
df.info()

# %%
df.head(8)

# %%
df.tail(3)

# %%
df.describe()

# %%
df.describe(include='O')

# %%
df.shape

# %%
df.columns

# %%
df.dtypes

# %%
type(df)

# %%
df.isnull().sum()

# %%
df.Sex.unique()

# %%
df.Sex.value_counts()

# %%
#Locate a value in the database
df.Sex[3]
df['Sex'][3]

# %% [markdown]
# ### Locaters and Ilocaters
# #### Locaters are name based access of rows and columns. If rows are not named, row numbers also work
# - df.loc[col_name,row_name]
# - df.loc[[list of col names],[list of row names]]
# - df.loc[[list of col_ names] start_row:end_row]
# #### Ilocaters are index based access of rows and columns.
# - df.loc[col_name,row_name]
# - df.loc[[list of col names],[list of row names]]
# - df.loc[start_col:end_col, start_row:end_row]
# #### Ilocaters are index based access of rows and colu

# %%
df

# %%
df.loc[493,'Name']

# %%
df.loc[493,:]   #df.loc[493] also retrieves the same row.

# %%
df.loc[493, ['Embarked','Name','Survived']]

# %%
df.loc[4:15,['Embarked','Name','SibSp']]

# %%
df.loc[[790,34,800,1],['Name','Embarked']]

# %%
df.iloc[[790,34,1],[3,6]]

# %%
#Filtering dataframe based on conditions
#Find all the passenger aged over 70 and their survival status
df.loc[df.Age>70,['Name','Survived']]

# %%
df

# %%
#Find all female passengers traveling alone
df.loc[(df.Sex=='female')&(df.SibSp==0)&(df.Parch==0),'Name']

# %% [markdown]
# - Get all names of passengers who boarded at 'Q'
# - Get the details of passengers who are traveling alone
# - Get the name and survival status of passengers who are traveling alone.
# - Get the name and age of female passengers who traveled in 3rd class.

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.reset_option('display.max_rows',None)
pd.reset_option('display.max_columns',None)

# %%
#Aggregations on the database - groupby
df.groupby("Sex").describe()

# %%
df.groupby('Sex').Age.mean()

# %%
#Sorting a dataframe
df.sort_values('Age')
df.sort_values('Age',ignore_index=True)
#df.sort_values('Age',ignore_index=True,inplace=True)

# %%
df.Survived.dtype

# %%
df.info()

# %%
df.Survived = pd.to_numeric(df.Survived,downcast='integer')

# %%
df.info()

# %%
df.Pclass = df.Pclass.astype('object')

# %%
df.info()

# %%
df.Pclass = pd.to_numeric(df.Pclass,downcast='integer')
df.Pclass = df.Pclass.astype('int')

# %% [markdown]
# #### Cleaning the data, Manipulating the data
# - Transformations
# - De-duplication - Removing the duplicates
# - Removing columns
# - Imputing values

# %%
df.drop_duplicates()  #Eliminate duplicate rows from dataframe
#df.drop_duplicates(inplace=True)

# %%
df.dropna()  #Drop those rows with null values

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.fillna(0)   #Fill a value in the empty cells - Imputing
df.fillna(value={'Sex':'male','Cabin':'Nothing','Embarked':'S'},inplace=True)  #Fill each column's null values with specific values

# %%
df.loc[df.Age.isnull(),'Age'] = df.Age.mean()    #Filter the null cells using loc and impute

# %%
#Dropping a column
df.drop(['PassengerId','Ticket'],axis=1,inplace=True)

# %%
#Transformations
df['Age_log'] = np.log(df.Age)

# %%
df['Family'] = df.SibSp + df.Parch

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch     Fare Cabin Embarked   Age_log  Family
# ...
